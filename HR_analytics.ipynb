# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Привет, меня зовут Александр Куимов. Я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты"😏 Надеюсь, тебя также не смутит, если я буду обращаться к тебе на "ты", но если это неудобно, обязательно скажи об этом!
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь реагировать на мои комментарии своими по шаблону, показанному чуть ниже. Это нужно, чтобы не создавалась путаница😉
#
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
#
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> В такой цветовой ячейке я прошу тебя оставлять свои комментарии. Если исправляешь проект на второй итерации и выше, не забывай пожалуйста указывать номер итерации, например, "Комментарий студента v.2".
# </div>
#
# <br/>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе датасаентистом. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓

# %% [markdown]
# # Сборный проект - 2

# %% [markdown]
# # Компания "Работа с заботой"

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# - HR - аналитики компании «Работа с заботой» помогают бизнесу оптимизировать управление персоналом
# - Бизнес предоставляет данные, а аналитики предлагают, как избежать финансовых потерь и оттока сотрудников
# - Внедрение машинного обучения на основании этих данных повысит точность и упростит работу
# - Компания предоставила данные с характеристиками сотрудников компании. Одной из этих характеристик является уровень удовлетворённости сотрудника работой в компании, где 0 — совершенно неудовлетворён, 1 — полностью удовлетворён

# %% [markdown]
# ## Цели

# %% [markdown]
# - Предсказать отток специалистов, а также их удовлетворённость работой
# - Сформулировать советы бизнесу и инсайты, опираясь на особенности обучения моделей

# %% [markdown]
# ## Задачи

# %% [markdown]
# - `Задача №1`: построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика
# - `Задача №2`: построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании

# %% [markdown]
# # Задача №1

# %% [markdown]
# ### Описание данных:
# - `id` — уникальный идентификатор сотрудника
# - `dept` — отдел, в котором работает сотрудник
# - `level` — уровень занимаемой должности
# - `workload` — уровень загруженности сотрудника
# - `employment_years` — длительность работы в компании (в годах)
# - `last_year_promo` — показывает, было ли повышение за последний год
# - `last_year_violations` — показывает, нарушал ли сотрудник трудовой договор за последний год
# - `supervisor_evaluation` — оценка качества работы сотрудника, которую дал руководитель
# - `salary` — ежемесячная зарплата сотрудника
# - `job_satisfaction_rate` — уровень удовлетворённости сотрудника работой в компании, целевой признак

# %% [markdown]
# ### План работы:

# %% [markdown]
# - Загрузка данных из датасета
# - Предобработка данных, корректировка регистра, удаление дубликатов
# - Исследовательский анализ данных, общее представление о распределении данных
# - Подготовка данных
# - Обучение моделей
# - Формулировка выводов по задаче №1

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Вижу твое добавленное описание и план проекта. Молодец! Это поможет тебе расставлять акценты в выводах

# %% [markdown]
# # Шаг 1. Загрузка данных

# %% [markdown]
# - Загрузка нужных версий библиотек

# %%
# !pip install -U scikit-learn
# !pip install -U shap
# !pip install -U matplotlib
# !pip install -U seaborn
# !pip install -U phik
# !pip install -U yellowbrick

# %% [markdown]
# - Импорт библиотек и инструментов

# %%
# Библиотеки
import pandas as pd
import seaborn as sns
import scipy.stats as st
import matplotlib.pyplot as plt
import numpy as np
import sklearn # версия 1.4.1.post1
import phik
import shap
#Инструменты из библиотек
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import (StandardScaler, OneHotEncoder, OrdinalEncoder, MinMaxScaler, RobustScaler, LabelEncoder)
from sklearn.linear_model import (LogisticRegression, LinearRegression)
from sklearn.neighbors import KNeighborsClassifier
from yellowbrick.model_selection import FeatureImportances
from sklearn.inspection import permutation_importance
from phik import phik_matrix
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.svm import SVC
from sklearn.metrics import (r2_score,
                             roc_auc_score,
                             confusion_matrix,
                             mean_squared_error,
                             root_mean_squared_error,
                             mean_absolute_error,
                             precision_score,
                             accuracy_score,
                             recall_score,
                             make_scorer
                            )

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера 0 <a class="tocSkip"> </h2>
#
# Я вижу, что исполнение ячеек с кодом идет не по порядку (это легко заметить по нумерации, должно быть 1, 2, 3 и т.д.). Перед отправкой проекта стоит проверять работоспособность кода — это можно сделать, нажав на панели Jupiter Hub ``Kernel`` и ``Restart & Run All`` (см скриншот ниже).
#
# ![](https://i.postimg.cc/yd19rYf6/Screenshot-428.png)
#
# Важно также убедиться, что все ячейки проекта исполнились - можно просто пролистать работу до конца и убедиться, что последняя ячейка исполнена. Такая проверка поможет тебе убедиться, что твоё решение будет должным образом воспроизведено во время ревью или во время передачи его заказчику - это очень важный этап, пренебрегать которым не стоит)
#
# На втором сборном проекте воспроизводимость - это жёсткий критерий, поэтому убедись, пожалуйста, что проект работает, чтобы мы могли продолжить работу над ним

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>Перезапустил проект, как указано в инструкции. Всё сработало без ошибок</b>
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b> Понял тебя

# %% [markdown]
# - Загрузка данных из датасетов

# %% [markdown]
# - Тренировочная выборка

# %%
train_job_satisf_rt_df = pd.read_csv('https://code.s3.yandex.net/datasets/train_job_satisfaction_rate.csv',
                                             sep = ',',
                                             decimal = '.'
                                            )

# %%
train_job_satisf_rt_df.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  155278       sales  junior   medium                 2              no
# 1  653870          hr  junior     high                 2              no
# 2  184592       sales  junior      low                 1              no
# 3  171431  technology  junior      low                 4              no
# 4  693419          hr  junior   medium                 1              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 0                   no                      1   24000                   0.58
# 1                   no                      5   38400                   0.76
# 2                   no                      2   12000                   0.11
# 3                   no                      2   18000                   0.37
# 4                   no                      3   22800                   0.20

# %%
train_job_satisf_rt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   3994 non-null   object
#  2   level                  3996 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 312.6+ KB

# %% [markdown]
# - Входные признаки тестовой выборки

# %%
test_features_df = pd.read_csv('https://code.s3.yandex.net/datasets/test_features.csv',
                                             sep = ',',
                                             decimal = '.'
                                            )

# %%
test_features_df.head()
# Out:
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary
# 0                   no                      5   28800
# 1                   no                      4   30000
# 2                   no                      4   19200
# 3                   no                      4   19200
# 4                   no                      5   40800

# %%
test_features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1998 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 140.8+ KB

# %% [markdown]
# - Целевой признак тестовой выборки

# %%
test_trgt_job_satisf = pd.read_csv('https://code.s3.yandex.net/datasets/test_target_job_satisfaction_rate.csv',
                                             sep = ',',
                                             decimal = '.'
                                            )

# %%
test_trgt_job_satisf.head()
# Out:
#        id  job_satisfaction_rate
# 0  130604                   0.74
# 1  825977                   0.75
# 2  418490                   0.60
# 3  555320                   0.72
# 4  826430                   0.08

# %%
test_trgt_job_satisf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB

# %% [markdown]
# - Комментарий по загрузке данных:
#     + В данных отсутствуют явные недочёты такие как неправильный регистр, ошибка в написании - то, что может броситься в глаза при поверхностном просмотре
#     + Осуществим более подробное изучение структуры данных и качества датасетов в следующем шаге - предобработка данных

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера  <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
#
# В шаге осмотра данных нужно использовать также метод info()

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента v2: <a class="tocSkip"> </h2>
#
# <b>Добавил осмотр данных методом info на этапе загрузки в задаче №1 и задаче №2</b>
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# # Шаг 2. Предобработка данных

# %% [markdown]
# ## 2.1 Анализ типов данных столбцов

# %%
train_job_satisf_rt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   3994 non-null   object
#  2   level                  3996 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 312.6+ KB

# %%
test_features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1998 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 140.8+ KB

# %%
test_trgt_job_satisf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB

# %% [markdown]
# - Типы данных столбцов порядке - исправления не требуются
# - При этом в датасетах `train_job_satisf_rt_df` и `test_features_df` в стобцах `dept` и `level` присутствуют пропуски

# %% [markdown]
# ## 2.2 Анализ пропусков

# %% [markdown]
# - Проверим информацию в столбцах с пропусками, а также выведем соответствующие строки

# %% [markdown]
# - Стобец `dept`

# %%
train_job_satisf_rt_df.loc[train_job_satisf_rt_df['dept'].isna()]
# Out:
#           id dept   level workload  employment_years last_year_promo  \
# 1526  694746  NaN  junior   medium                 5              no
# 1630  814624  NaN  junior   medium                 3              no
# 1633  475114  NaN  junior     high                 4              no
# 2781  497243  NaN  junior   medium                 1              no
# 2975  168668  NaN  junior      low                 3              no
# 3866  641150  NaN  junior      low                 3              no
#
#      last_year_violations  supervisor_evaluation  salary  \
# 1526                   no                      4   21600
# 1630                   no                      4   24000
# 1633                   no                      4   31200
# 2781                   no                      3   26400
# 2975                   no                      4   18000
# 3866                  yes                      4   12000
#
#       job_satisfaction_rate
# 1526                   0.62
# ...

# %%
test_features_df.loc[test_features_df['dept'].isna()]
# Out:
#           id dept   level workload  employment_years last_year_promo  \
# 191   609865  NaN  junior   medium                 1              no
# 1196  832342  NaN  junior   medium                 1              no
#
#      last_year_violations  supervisor_evaluation  salary
# 191                    no                      1   20400
# 1196                   no                      4   28800

# %% [markdown]
# - Столбец `level`

# %%
train_job_satisf_rt_df.loc[train_job_satisf_rt_df['level'].isna()]
# Out:
#           id   dept level workload  employment_years last_year_promo  \
# 1209  631073  sales   NaN   medium                 1              no
# 1469  416327  sales   NaN      low                 1              no
# 1745  135043  sales   NaN   medium                 1              no
# 2522  998838  sales   NaN   medium                 1              no
#
#      last_year_violations  supervisor_evaluation  salary  \
# 1209                   no                      4   27600
# 1469                   no                      5   18000
# 1745                   no                      3   26400
# 2522                   no                      5   27600
#
#       job_satisfaction_rate
# 1209                   0.66
# 1469                   0.73
# 1745                   0.30
# 2522                   0.71

# %%
test_features_df.loc[test_features_df['level'].isna()]
# Out:
#          id   dept level workload  employment_years last_year_promo  \
# 312  471990  sales   NaN      low                 1              no
#
#     last_year_violations  supervisor_evaluation  salary
# 312                   no                      3   12000

# %% [markdown]
# - Проверим уникальность информации в столбцах, в которых есть пропуски

# %%
train_job_satisf_rt_df['dept'].unique()
# Out:
# array(['sales', 'hr', 'technology', 'purchasing', 'marketing', nan],
#       dtype=object)

# %%
train_job_satisf_rt_df['level'].sort_values(ascending = True).unique()
# Out:
# array(['junior', 'middle', 'sinior', nan], dtype=object)

# %%
test_features_df['dept'].sort_values(ascending = True).unique()
# Out:
# array([' ', 'hr', 'marketing', 'purchasing', 'sales', 'technology', nan],
#       dtype=object)

# %%
test_features_df['level'].sort_values(ascending = True).unique()
# Out:
# array(['junior', 'middle', 'sinior', nan], dtype=object)

# %% [markdown]
# - Ошибка написания слова senior ("sinior") - столбец `level`
# - В датасете `test_features` в столбце `dept` присутствует пробел, который тоже нужно рассмотреть

# %%
train_job_satisf_rt_df['level'] = train_job_satisf_rt_df['level'].replace(to_replace = 'sinior', value = 'senior')
test_features_df['level'] = test_features_df['level'].replace(to_replace = 'sinior', value = 'senior')

# %%
train_job_satisf_rt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   3994 non-null   object
#  2   level                  3996 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 312.6+ KB

# %%
test_features_df.loc[test_features_df['dept'] == ' ']
# Out:
#           id dept   level workload  employment_years last_year_promo  \
# 1699  822186       middle   medium                 3              no
#
#      last_year_violations  supervisor_evaluation  salary
# 1699                   no                      4   38400

# %% [markdown]
# - Данный случай можно также расценивать как пропуск
# - Заменим его np.nan. При кодировании модель сама заменит пропуск

# %%
test_features_df['workload'] = test_features_df['workload'].replace(to_replace = ' ', value = np.nan)
test_features_df['dept'] = test_features_df['dept'].replace(to_replace = ' ', value = np.nan)
test_features_df['dept'].sort_values(ascending = True).unique()
# Out:
# array(['hr', 'marketing', 'purchasing', 'sales', 'technology', nan],
#       dtype=object)

# %% [markdown]
# - Замена проведена

# %% [markdown]
# - Комментарий:
#     + Несмотря на то что в датасете присутствуют пропуски, оставим их без изменений. На этапе обучения модели пропуски заполнит SimpleImputer
#     + Данные пропуски могут быть вызваны отсутствием определённого названия у должности либо отсутствием уровней в этой профессии

# %% [markdown]
# ## 2.3 Поиск дубликатов

# %%
train_job_satisf_rt_df.duplicated().sum()
# Out:
# 0

# %%
test_features_df.duplicated().sum()
# Out:
# 0

# %%
test_trgt_job_satisf.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - Явные дубликаты в датасете отсутствуют
# - Проанализируем столбцы с данными типа object, чтобы выявить неявные дубликаты

# %% [markdown]
# ## 2.4 Поиск неявных дубликатов

# %% [markdown]
# - Датасет `train_job_satisf_rt_df`

# %%
# Запишем функцию для анализа значений в столбцах типа object
def return_unique(df, column):
    print(df[column].sort_values(ascending = True).unique())
    print()

# %%
columns_check = ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']
for column in columns_check:
    return_unique(train_job_satisf_rt_df, column)
# Out:
# ['hr' 'marketing' 'purchasing' 'sales' 'technology' nan]
#
# ['junior' 'middle' 'senior' nan]
#
# ['high' 'low' 'medium']
#
# ['no' 'yes']
#
# ['no' 'yes']

# %%
columns_check = ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']
for column in columns_check:
    return_unique(test_features_df, column)
# Out:
# ['hr' 'marketing' 'purchasing' 'sales' 'technology' nan]
#
# ['junior' 'middle' 'senior' nan]
#
# ['high' 'low' 'medium' nan]
#
# ['no' 'yes']
#
# ['no' 'yes']

# %%
test_features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1997 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               1999 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 140.8+ KB

# %%
columns_check = ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']
for column in columns_check:
    return_unique(test_features_df, column)
# Out:
# ['hr' 'marketing' 'purchasing' 'sales' 'technology' nan]
#
# ['junior' 'middle' 'senior' nan]
#
# ['high' 'low' 'medium' nan]
#
# ['no' 'yes']
#
# ['no' 'yes']

# %%
test_features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1997 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               1999 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 140.8+ KB

# %% [markdown]
# - Пробелы удалены
# - В случае с датасетом `train_job_satisf_rt_df` неявные дубликаты отсутствуют

# %%
test_features_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - В датасете `test_features_df` неявные дубликаты также отсутствуют

# %% [markdown]
# - Вывод по предобработке данных:
#     + Были обнаружены пробелы в столбцах и заменены на np.nan
#     + Исправлено написание слова sinior на senior
#     + Пропуски в данных будут устранены в пайплайне
#     + Регистр названий столбцов корректный
#     + Явные и неявные дубликаты отсутствуют во всех датасетах

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Аномалия обработана корректно. В целом она могла бы быть обработана и в `Pipeline`, при настройке энкодеров на обработку новых значений признаков, которые не были на момент обучения энкодера

# %% [markdown]
# # Шаг 3. Исследовательский анализ

# %% [markdown]
# - Функции для построения диаграмм, гистограмм и других графических представлений данных

# %%
# Функиця для построения круговых диаграмм
def pie_build(df, column, support_column, title, i, j):
    df_column = df.pivot_table(index = column, values = support_column, aggfunc = ['count'])
    df_column.columns = ['quantity']
    df_column['quantity'] = df_column['quantity'] / df[column].count()
    axes[i, j].set_title(title);
    axes[i, j].pie(df_column['quantity'], autopct='%1.2f%%');
    axes[i, j].legend(
    bbox_to_anchor = (1.0, 1.0),
    loc = 'upper left', labels = df_column.index);

# %%
# Функиця для построения одной круговой диаграммы
def pie_build_one(df, column, support_column, title):    
    df_column = df.pivot_table(index = column, values = support_column, aggfunc = ['count'])
    df_column.columns = ['quantity']
    df_column['quantity'] = df_column['quantity'] / df[column].count()
    ax.set_title(title);
    ax.pie(df_column['quantity'], autopct='%1.2f%%');
    ax.legend(
    bbox_to_anchor = (1.0, 1.0),
    loc = 'upper left', labels = df_column.index);

# %%
# функция для построения гистограмм
def hist_build(df, column, hist_color, xlabel, ylabel, title, i, j, quant_of_bins, more_than_one_row):
    if more_than_one_row:
        axes[i, j].set_title(title) 
        axes[i, j].hist(df[column], bins = quant_of_bins, color = hist_color)
        axes[i, j].set_xlabel(xlabel)
        axes[i, j].set_ylabel(ylabel)
    else:
        axes[j].set_title(title) 
        axes[j].hist(df[column], bins = quant_of_bins, color = hist_color)
        axes[j].set_xlabel(xlabel)
        axes[j].set_ylabel(ylabel)

# %%
# функция для построения одной гистограммы
def hist_build_one(df, column, hist_color, xlabel, ylabel, title, quant_of_bins):
        ax.set_title(title) 
        ax.hist(df[column], bins = quant_of_bins, color = hist_color)
        ax.set_xlabel(xlabel)
        ax.set_ylabel(ylabel)

# %%
# Функция для построения ящиков с усами
def boxplot_build(df, column, xlabel, title, i, j, left_lim, right_lim):
    axes[i, j].boxplot(df[[column]], vert = False)
    axes[i, j].set_title(title) 
    axes[i, j].set_xlabel(xlabel)
    axes[i, j].set_xlim(left_lim, right_lim)

# %%
# Функция для построения ящиков с усами
def boxplot_build_one(df, column, xlabel, title, left_lim, right_lim):
    ax.boxplot(df[[column]], vert = False)
    ax.set_title(title) 
    ax.set_xlabel(xlabel)
    ax.set_xlim(left_lim, right_lim)

# %% [markdown]
# ## Датасет `train_job_satisf_rt_df`

# %% [markdown]
# - Построим круговые диаграммы для категориальных признаков. Исключим при построении пропуски, чтобы не переполнять легенду ненужной информацией

# %%
column_to_science = columns_check
fig, axes = plt.subplots(nrows = 3, ncols = 2, figsize = (14, 20))
i = 0
for column in column_to_science:
   pie_build(train_job_satisf_rt_df, column, 'id', 'Распределение ' + column, i // 2, i % 2)
   i += 1

# %% [markdown]
# - Количественные данные

# %%
num_columns = ['employment_years', 'supervisor_evaluation', 'salary', 'job_satisfaction_rate']
param_quant_of_bins = [10, 5, 15, 15]
param_lim_left = [0, 0, 0, 0]
param_lim_right = [15, 8, 120000, 1.1]
i = 0
fig, axes = plt.subplots(nrows = 4, ncols = 2, figsize = (12, 25))
for column in num_columns:
    hist_build(train_job_satisf_rt_df,
               column,
               'green',
               'Значения ' + column,
               'Количество',
               'Распределение ' + column,
               i,
               0,
               param_quant_of_bins[i],
               True
              )
    
    boxplot_build(train_job_satisf_rt_df,
                  column,
                  'Значения ' + column,
                  'Диаграмма ящик с усами для ' + column,
                  i,
                  1,
                  param_lim_left[i],
                  param_lim_right[i]       
                 )
    i += 1

# %% [markdown]
# - Признак `supervisor_evaluation` обладает дискретным распределением от 1 до 5
# - Число людей по мере увеличения стажа всё меньше, что логично
# - Зарплата обладает ненормальным распределением, средняя зарплата сильно смещена влево. Вероятно рассматриваемые профессии по - разному оплачиваются, по этой причине и возникает такое необычное распределение. Этим же объясняется наличие выбросов в столбце `salary`, но они находятся вблизи квартиля в 75%. Таким образом, нет необходимости удалять эти данные
# - В остальном с данными всё в порядке

# %% [markdown]
# ## Датасет `test_features_df`

# %% [markdown]
# - Категориальные данные

# %%
column_to_science = columns_check
fig, axes = plt.subplots(nrows = 3, ncols = 2, figsize = (14, 20))
i = 0
for column in column_to_science:
   pie_build(test_features_df, column, 'id', 'Распределение ' + column, i // 2, i % 2)
   i += 1

# %% [markdown]
# - Количественные данные

# %%
num_columns = ['employment_years', 'supervisor_evaluation', 'salary']
param_quant_of_bins = [10, 5, 15]
param_lim_left = [0, 0, 0]
param_lim_right = [15, 8, 120000]
i = 0
fig, axes = plt.subplots(nrows = 3, ncols = 2, figsize = (12, 18))
for column in num_columns:
    hist_build(test_features_df,
               column,
               'orange',
               'Значения ' + column,
               'Количество',
               'Распределение ' + column,
               i,
               0,
               param_quant_of_bins[i],
               True
              )
    
    boxplot_build(test_features_df,
                  column,
                  'Значения ' + column,
                  'Диаграмма ящик с усами для ' + column,
                  i,
                  1,
                  param_lim_left[i],
                  param_lim_right[i]       
                 )
    i += 1

# %%
test_features_df['employment_years'].describe()
# Out:
# count    2000.000000
# mean        3.666500
# std         2.537222
# min         1.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        10.000000
# Name: employment_years, dtype: float64

# %%
#test_features_df['supervisor_evaluation'].describe()

# %%
test_features_df['salary'].describe()
# Out:
# count     2000.000000
# mean     34066.800000
# std      15398.436729
# min      12000.000000
# 25%      22800.000000
# 50%      30000.000000
# 75%      43200.000000
# max      96000.000000
# Name: salary, dtype: float64

# %% [markdown]
# - Для датасета `test_trgt_job_satisf` не будем проводить исследовательский анализ
# - Распределение данных для датасета `test_features` аналогично датасету `train_job_satisf_rt_df`

# %% [markdown]
# ## Матрица корреляций для датасета `train_job_satisf_rt_df`

# %%
interval_cols = ['employment_years',
                 'supervisor_evaluation',
                 'salary'
    
]

# %%
matrix_corr= phik_matrix(train_job_satisf_rt_df.drop('id', axis = 1), interval_cols = interval_cols);
fig, ax = plt.subplots(figsize = (7, 7));
sns.heatmap(matrix_corr, annot = True, fmt='.2f');

# %% [markdown]
# -  Мультиколлинеарность с целевым признаком `job_satisfaction_rate` отсутствует
# -  Остальная информация представлена на матрице корреляций:
#     + Высокая корреляция с признаком `super_visor_evaluation` (0.73)
#     + Средняя корреляция с признаком `last_year_violations` (0.59)
#     + Умеренная корреляция с признаками  `last_year_promo`, `employment_years` (0.33, 0.43 соответственно)
#     + У остальных признаков с целевым наблюдается низкая корреляция

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Отлично, что при использовании phik настроен параметр interval_cols)

# %% [markdown]
# ### Вывод по исследовательскому анализу данных:
# - Все необходимые диаграммы были построены
# - Критические ошибки в данных исправлены
# - Выбросы в данных присутствуют, но удалять их нецелесообразно. Аномалии отсутствуют

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Верно!👍:\
# </b> Мне интересно было изучить проведенный исследовательский анализ данных, твои графики, осмысленный и красочный графический анализ. Найдены очень интересные закономерности)

# %% [markdown]
# # Шаг 4. Подготовка данных

# %% [markdown]
# - Создадим пайплайн для обучения линейной модели и деревья решений(в данной задаче предсказываем непрерывный количественный признак, поэтому применяем эти модели)

# %%
# Зададим константы
RANDOM_STATE = 77

# %% [markdown]
# - К количественным признакам отнесём : `employment_years`, `supervisor_evaluation`, `salary`
# - К порядковым : `level`, `workload`
# - К категориальным : `dept`, `last_year_promo`, `last_year_violations`
# - Целевой признак : `job_satisfaction_rate`

# %%
# Объявим категеориальные и количественные признаки
ohe_columns = [
               'dept',
               'last_year_promo',
               'last_year_violations'
              ]

ord_columns = [
               'level',
               'workload'
              ]

num_columns = [
               'employment_years',
               'supervisor_evaluation',
               'salary',
              ]

# %%
# Разделение датасета
X_train = train_job_satisf_rt_df.drop(['job_satisfaction_rate', 'id'], axis = 1)
y_train = train_job_satisf_rt_df['job_satisfaction_rate']

# %%
# SimpleImputer + OHE
ohe_pipe = Pipeline(
    [
        (
            'simpleImputer',
             SimpleImputer(missing_values = np.nan, strategy = 'most_frequent')
        ),
        (
            'ohe',
             OneHotEncoder(drop = 'first', handle_unknown = 'ignore', sparse_output = False)
        )
    ]
)

# %%
# SimpleImputer + ORD + SimpleImputer
ord_pipe = Pipeline(
    [
        (
            'simpleImputer_before_ord',
            SimpleImputer(missing_values = np.nan, strategy = 'most_frequent')
        ),
        (
            'ord',
            OrdinalEncoder(
                categories = [
                    ['junior', 'middle', 'senior'],
                    ['low', 'medium', 'high']
                ],
                handle_unknown = 'use_encoded_value', unknown_value = np.nan
            )
                    
        ),
        (
            'simpleImputer_after_ord',
            SimpleImputer(missing_values = np.nan, strategy = 'most_frequent')
        )                
    ]       
)

# %%
# Пайплайн для кодирования и масштабирования данных
data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pipe, ohe_columns),
        ('ord', ord_pipe, ord_columns),
        ('num', MinMaxScaler(), num_columns)
    ],
    remainder = 'passthrough'
)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
#
# Отлично, что использовано более одного энкодера, взятого из готовой реализации библиотеки sklearn)

# %%
# Словарь для RandomimzedSearchCV
param_distributions = [
            {
                # Описание DecisionTreeClassifier
                'models' : [DecisionTreeRegressor(random_state = RANDOM_STATE)],
                'models__max_depth' : range(5, 13),
                'models__min_samples_split' : range(5, 13),
                'preprocessor__num' : [StandardScaler(), MinMaxScaler(), RobustScaler()]
            },
            {
                # Описание LinearRegression
                'models' : [LinearRegression()
                           ],
                'preprocessor__num' : [StandardScaler(), MinMaxScaler(), RobustScaler()]
            },
]

# %%
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeRegressor(random_state = RANDOM_STATE)) 
])

# %% [markdown]
# # Шаг 5. Обучение моделей

# %% [markdown]
# - Метрика SMAPE

# %%
def custom_metric(y_true, y_pred):
    error = np.abs(y_true - y_pred)
    scale = (np.abs(y_true) + np.abs(y_pred)) / 2
    return np.mean(error / scale) * 100

# %%
# Создание метрики SMAPE
SMAPE = make_scorer(custom_metric, greater_is_better = False)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Верно, что задаешь параметр `greater_is_better=False`. Дело в том, что разработчики пакета `sklearn` при создании функций `cross_val_score` и `GridSearchCV` утвердили соглашение: возвращаемые результаты вычислений данных функций должны соответствовать задаче максимизации (чем большее значение метрики получаем, тем лучше). При этом обратная задача минимизации может быть осуществлена через максимизацию метрики, домноженной на -1. Об этом можно чуть подробнее почитать в документации пакета, правда она на английском. Оставлю <a href = 'https://scikit-learn.org/stable/modules/model_evaluation.html'>ссылку</a>.

# %% [markdown]
# - Обучение моделей

# %%
# Обучим и найдём лучшую модель при помощи инструмента автоматизированного поиска RandomizedSearchCV
randomized_search = RandomizedSearchCV(
                        pipe_final,
                        param_distributions = param_distributions,
                        cv = 5,
                        scoring = SMAPE,
                        random_state = RANDOM_STATE,
                    )
randomized_search.fit(X_train, y_train)
print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['dept', 'last_year_promo',
#                                                    'last_year_violations']),
#                                                  ('ord',
# ...

# %%
print('Метрика лучшей модели на тренировочной выборке:', round((randomized_search.best_score_), 3))
# Out:
# Метрика лучшей модели на тренировочной выборке: -15.03

# %% [markdown]
# - Проверим метрику на тестовой выборке, предварительно сформировав выборки входных и целевого признака

# %%
test_features_df_new = test_features_df # для второй задачи сохранил оригинал
test_features_df = test_features_df.merge(test_trgt_job_satisf, on = 'id', how = 'left')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Хорошо, что объединение происходит по `id`

# %%
X_test = test_features_df.drop(['job_satisfaction_rate', 'id'], axis = 1)
#y_test = test_trgt_job_satisf['job_satisfaction_rate']
y_test = test_features_df['job_satisfaction_rate']

# %%
y_pred = randomized_search.predict(X_test)
print('Метрика лучшей модели на тестовой выборке:', round(custom_metric(y_test, y_pred), 3))
# Out:
# Метрика лучшей модели на тестовой выборке: 13.978

# %% [markdown]
# - На тестовой выборке метрика $SMAPE <= 15$, как и требовалось по заданию

# %%
best_model = randomized_search.best_estimator_

# %% [markdown]
# - Оценим вклад каждого признака на принятие решений модели

# %%
result = permutation_importance(best_model, X_test, y_test, scoring = SMAPE);

feature_importance = pd.DataFrame({'Feature': X_test.columns, 'Importance': result['importances_mean']});
feature_importance = feature_importance.sort_values('Importance', ascending=True);
sns.set_style('white');
feature_importance.plot(x = 'Feature', y='Importance', kind = 'barh', figsize=(10, 6));

# %% [markdown]
# - Вывод по полученной диаграмме:
#     + `supervisor_evaluation` оказывает наибольший вклад при выборе решения моделью (оценка работодателя)
#     + `employment_years`, `salary`, `level` - в первом приближении равны по значимости, при этом их вклад на принятие решение в 2.5 меньше, чем признака `supervisor_evaluation`
#     + `last_year_violations`, `workload`, `dept` менее значимы (вклад в принятие решений моделью в 5 раз меньше, чем `super_visor_violations`)
#     + `last_year_promo` почти не влияет на целевой признак в сравнении с другими входными признаками

# %% [markdown]
# - Анализ остатков

# %%
residuals = y_test - y_pred

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (10, 5));
axes[0].hist(x = residuals, bins = 30);
axes[0].set_title('Гистограмма распределения остатков');
axes[0].set_xlabel('Остатки');

axes[1].scatter(x = y_pred, y = residuals);
axes[1].set_title('Диаграмма рассеяния остатков');
axes[1].set_xlabel('Предсказания модели');
axes[1].set_ylabel('Остатки');

# %% [markdown]
# - Остатки распределены нормально, смещений нет
# - На диаграмме рассеяния присутствует однородность вдоль абсциссы, что также свидетельствует о хороших предсказаниях модели

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что не забываешь оценить важность признаков модели
#
#
# * Дополнительно впоследствии можно заново пересобирать лучшую модель на ограниченном наборе признаков (а не заранее, чтобы была возможность контролировать спад качества), чтобы облегчить ее (может потребоваться заново подобрать параметры). Это может дать небольшой прирост в качестве за счет избавления от зашумленности, главное не переборщить

# %% [markdown]
# # Шаг 6. Выводы

# %% [markdown]
# - Лучше всего справилась модель дерева регрессии с максимальной глубиной равной 12 (`max_depth`) и минимальным количеством примеров, которые нужны для разделения узла дерева решений, равным 11 (`min_samples_split`).
# - Эта модель оказалась лучшей, так как она использовала наибольшие значения гиперпараметров из предоставленных, тем самым достигнув нужной точности. На диаграммах, которые демонстрируют качество работы модели, видно, что остатки распределены нормально без смещения, а на диаграмме присутствует однородность вдоль абсциссы
# - По итогам обучения можно заключить следующее:
#     + Наибольшее влияние на целевой признак оказывает оценка работодателя (`supervisor_evaluation`)
#     + Следующие по значимости признаки - длительность работы в компании, зарплата и уровень занимаемой должности (`employment_years`, `salary` и `level`)
#     + Остальные признаки не такое большое значение оказывают на принятие решений

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Тестирование лучшей модели проведено правильно

# %% [markdown]
# # Задача №2

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# В этой задаче по аналогичным заданиям и действиям в проекте -  аналогичные замечания (я их привел выше в первой части проекта), без исправления которых проект принят не будет.
#
# Новые неповторяющиеся замечания будут даны ниже отдельно

# %% [markdown]
# ## Описание данных

# %% [markdown]
# - Входные признаки аналогичны предыдущим датасетам

# %% [markdown]
# # Шаг 1. Загрузка данных

# %%
train_quit_df = pd.read_csv('https://code.s3.yandex.net/datasets/train_quit.csv',
                            sep = ',',
                            decimal = '.'
                           )

# %%
train_quit_df.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      4   54000   no
# 1                   no                      4   27600   no
# 2                   no                      1   37200   no
# 3                  yes                      3   24000  yes
# 4                   no                      5   25200   no

# %%
train_quit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   4000 non-null   object
#  2   level                  4000 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   quit                   4000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 312.6+ KB

# %%
test_target_quit_df = pd.read_csv('https://code.s3.yandex.net/datasets/test_target_quit.csv',
                            sep = ',',
                            decimal = '.'
                           )

# %%
test_target_quit_df.head()
# Out:
#        id quit
# 0  999029  yes
# 1  372846   no
# 2  726767   no
# 3  490105   no
# 4  416898  yes

# %%
test_target_quit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2000 non-null   int64
#  1   quit    2000 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 31.4+ KB

# %% [markdown]
# ## Выводы по осмотру данных

# %% [markdown]
# - Были загружены датасеты `train_quit_df` и `test_target_quit_df`, датасет `test_features_df` был уже загружен и рассмотрен в задаче №1
# - По результатам вызова метода info() стало известно, что в обоих датасетах отсутствуют пропуски(по крайней мере значения NaN)
# - Регистры названий столбцов правильные, с написанием также нет проблем
# - При загрузке датасетов были учтены особенности разделения данных, а также символа, который разделяет целую и вещественную часть, поэтому типы данных соответствуют смысловому значению столбцов
# - Более подробное изучение данных проведём на этапе предобработки

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера 2  <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
#
# В  конце шага осмотра данных нужно написать развёрнутые выводы по результатам осмотра данных. Прошу прощения, что не указал в прошлый раз

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента v2: <a class="tocSkip"> </h2>
#
# <b>Добавил вывод по осмотру данных в задаче №2</b>
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# # Шаг 2. Предобработка данных

# %% [markdown]
# ## 2.1 Проверка типов данных

# %%
train_quit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   4000 non-null   object
#  2   level                  4000 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   quit                   4000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 312.6+ KB

# %%
test_target_quit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2000 non-null   int64
#  1   quit    2000 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 31.4+ KB

# %% [markdown]
# - Типы данных столбцов в порядке
# - Пропуски в датасетах отсутствуют
# - Датасет `test_features_df` не требует предобработки, так как она была уже сделана в задаче №1

# %% [markdown]
# ## 2.2 Поиск явных дубликатов

# %%
train_quit_df.duplicated().sum()
# Out:
# 0

# %%
test_target_quit_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 2.3 Поиск неявных дубликатов

# %%
columns_check = ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']
for column in columns_check:
    return_unique(train_quit_df, column)
# Out:
# ['hr' 'marketing' 'purchasing' 'sales' 'technology']
#
# ['junior' 'middle' 'sinior']
#
# ['high' 'low' 'medium']
#
# ['no' 'yes']
#
# ['no' 'yes']

# %%
train_quit_df['level'] = train_quit_df['level'].replace(to_replace = 'sinior', value = 'senior')
train_quit_df['level'].sort_values(ascending = True).unique()
# Out:
# array(['junior', 'middle', 'senior'], dtype=object)

# %% [markdown]
# - Все недочёты были исправлены
# - Пропуски в данных будут заполнены в пайплайне при обучении моделей

# %% [markdown]
# # Шаг 3. Исследовательский анализ данных

# %% [markdown]
# ## 3.1 Исследовательский анализ данных

# %% [markdown]
# ## Датасет `train_quit_df`

# %% [markdown]
# - Категориальные данные

# %%
cat_cols = ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations', 'quit']

# %%
num_cols = ['employment_years', 'supervisor_evaluation', 'salary']

# %%
fig, axes = plt.subplots(nrows = 3, ncols = 2, figsize = (14, 20))
i = 0
for column in cat_cols:
   pie_build(train_quit_df, column, 'id', 'Распределение ' + column, i // 2, i % 2)
   i += 1

# %% [markdown]
# - Существенно то, что соотношение значений целевого признака `quit` 'no' и 'yes' - 72% и 28%, что может привести к дисбалансу при обучении моделей. Поэтому на этапе разделения данных необходимо стратифицировать выборки
# - Остальная информация визулизирована

# %% [markdown]
# - Количественные данные

# %%
num_columns = ['employment_years', 'supervisor_evaluation', 'salary']
param_quant_of_bins = [10, 5, 15]
param_lim_left = [0, 0, 0]
param_lim_right = [15, 8, 120000]
i = 0
fig, axes = plt.subplots(nrows = 3, ncols = 2, figsize = (12, 18))
for column in num_columns:
    hist_build(train_quit_df,
               column,
               'lightblue',
               'Значения ' + column,
               'Количество',
               'Распределение ' + column,
               i,
               0,
               param_quant_of_bins[i],
               True
              )
    
    boxplot_build(train_quit_df,
                  column,
                  'Значения ' + column,
                  'Диаграмма ящик с усами для ' + column,
                  i,
                  1,
                  param_lim_left[i],
                  param_lim_right[i]       
                 )
    i += 1

# %% [markdown]
# - Распределение данных аналогично другим датасетам, так что ничего нового здесь сказать нельзя

# %% [markdown]
# ## 3.2 Портрет "уволившегося сотрудника"

# %%
# Функиця для построения круговых диаграмм
def pie_build_short(df_column, column, title, i, j):
    df_column[column] = df_column[column].apply(lambda x: x / df_column[column].count())
    axes[i, j].set_title(title);
    axes[i, j].pie(df_column[column], autopct='%1.2f%%');
    axes[i, j].legend(
    bbox_to_anchor = (1.0, 1.0),
    loc = 'upper left', labels = df_column.index);

# %%
def scatterplot_build(df, quant_attribute, target, cat_attribute):
    plt.figure(figsize = (10, 10));
    sns.scatterplot(data = df, x = quant_attribute, y = target, style = cat_attribute, hue = cat_attribute)
    plt.xlabel(quant_attribute);
    plt.ylabel(target);
    ax.legend(
    bbox_to_anchor = (1.0, 1.0),
    loc = 'upper left', labels = df[cat_attribute])

# %% [markdown]
# - Проведём анализ увольнений по отделам - `dept`

# %%
dept_train_quit_df = train_quit_df[['id','dept', 'quit']].pivot_table(index = ['quit'], columns = ['dept'], aggfunc = ['count'])
dept_train_quit_df.head()
# Out:
#      count
#         id
# dept    hr marketing purchasing sales technology
# quit
# no     348       419        422  1031        652
# yes    116       163        166   407        276

# %%
dept_train_quit_df.columns = ['hr', 'marketing', 'purchasing', 'sales', 'technology']

# %%
dept_train_quit_df.head()
# Out:
#        hr  marketing  purchasing  sales  technology
# quit
# no    348        419         422   1031         652
# yes   116        163         166    407         276

# %%
fig, axes = plt.subplots(nrows = 3, ncols = 2, figsize = (10, 15))
i = 0
dept_col = ['hr', 'marketing', 'purchasing', 'sales', 'technology']
for column in dept_col:
   pie_build_short(dept_train_quit_df, column, 'Распределение ' + column, i // 2, i % 2)
   i += 1

# %% [markdown]
# - В процентном соотношении больше всего увольнений приходится на отдел `technology` - почти 30%
# - Меньше всего увольнений в отделе `hr` - 25%
# - В остальных отделах - около 28%

# %% [markdown]
# - Проанализируем с каким уровнем должности (`level`) чаще всего увольняются сотрудники

# %%
level_train_quit_df = train_quit_df[['id','level', 'quit']].pivot_table(index = ['quit'], columns = ['level'], aggfunc = ['count'])
level_train_quit_df.head()
# Out:
#        count
#           id
# level junior middle senior
# quit
# no       946   1586    340
# yes     1003    108     17

# %%
level_train_quit_df.columns = ['junior', 'middle', 'senior']

# %%
level_train_quit_df.head()
# Out:
#       junior  middle  senior
# quit
# no       946    1586     340
# yes     1003     108      17

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (10, 10))
i = 0
level_col = ['junior', 'middle', 'senior']
for column in level_col:
   pie_build_short(level_train_quit_df, column, 'Распределение ' + column, i // 2, i % 2)
   i += 1

# %% [markdown]
# - Как видно из построенных диаграмм, чаще всего увольняются сотрудники уровня `junior`. Их больше половины
# - В то время как для уровня `middle` этот показатель составляет 6.4%, а `senior` - 4.8%

# %% [markdown]
# - Посмотрим, как распределены соотношения уволившихся людей в зависимости от загруженности `workload`

# %%
workload_train_quit_df = train_quit_df[['id','workload', 'quit']].pivot_table(index = ['quit'], columns = ['workload'], aggfunc = ['count'])
workload_train_quit_df.head()
# Out:
#          count
#             id
# workload  high  low medium
# quit
# no         553  689   1630
# yes        121  519    488

# %%
workload_train_quit_df.columns = ['high', 'low', 'medium']

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (10, 10))
i = 0
level_col = ['low', 'medium', 'high']
for column in level_col:
   pie_build_short(workload_train_quit_df, column, 'Распределение ' + column, i // 2, i % 2)
   i += 1

# %% [markdown]
# - Наиболее часто увольняются сотрудники со низким уровнем загруженности `junior` - 43%
# - Почти в два раза меньше увольнений у сотрудников со средним уровнем загруженности - 23%
# - Меньше всех остальных увольняются сотрудники с высоким уровнем нагрузки - 18%
# - Иными словами, чем выше загруженность - тем меньше сотрудники увольняются

# %% [markdown]
# - Сделаем срез данных по всем вышеперечисленным категориям и сформируем сводную таблицу со средними значениями зарплат уволившихся сотрудников и оставшихся в компании

# %%
salary_pivot_table = (train_quit_df[['id','workload', 'dept', 'level', 'quit', 'salary']]
                      .pivot_table(index = ['dept', 'level', 'workload', 'quit'], values = ['salary'], aggfunc = ['mean']))

# %%
salary_pivot_table.columns = ['mean_salary']
salary_pivot_table['mean_salary'] = salary_pivot_table['mean_salary'].round()

# %%
for column in dept_col:
    display(salary_pivot_table.loc[salary_pivot_table.index.get_level_values(0) == column])
    print(' ')
    print(' ')
# Out:
#                            mean_salary
# dept level  workload quit
# hr   junior high     no        39360.0
#                      yes       38000.0
#             low      no        18178.0
#                      yes       15882.0
#             medium   no        26772.0
#                      yes       25674.0
#      middle high     no        55227.0
#                      yes       62400.0
#             low      no        25445.0
#                      yes       24857.0
#             medium   no        40176.0
#      senior high     no        74325.0
#             low      no        31371.0
#             medium   no        55341.0
#                      yes       60000.0
#                                 mean_salary
# dept      level  workload quit
# marketing junior high     no        38057.0
#                           yes       36533.0
#                  low      no        18529.0
#                           yes       15521.0
#                  medium   no        28826.0
# ...

# %% [markdown]
# - Рассматривая сводные таблицы, можно заключить, что у уволившихся сотрудников средняя зарплата меньше, чем у оставшихся работать в компании
# - Данное наблюдение нарушается в случае, если специалист высокого уровня `senior` или `medium` с высоким уровнем нагрузки (не во всех отделах - `dept`). В этом случае у ушедших сотрудников зарплата больше(вероятно в другой организации предложили более высокий уровень заработной платы или лучшие условия работы при прочих равных). Но это скорее исключение, чем правило

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что используешь относительные значения в описании портрета уволившегося сотрудника

# %% [markdown]
# ## 3.3 Связь уровня удовлетворённости с увольнением

# %% [markdown]
# - Построим диаграмму рассеяния между увольнением и удовлетворённостью
# - При этом предскажем значения `job_satisfaction_rate` для датасетов `test_features_df_new`

# %%
X_train_new = train_quit_df.drop(['quit', 'id'], axis = 1)

# %% [markdown]
# - Немного странно, что связь `quit` и `job_satisfaction_rate` необходимо проверить на тестовой выборке. Но я сделал, как написано в задании

# %% [markdown]
# - Предскажем признак `job_satisfaction_rate` для датасета `test_features_df`
# - Затем построим гистограммы с распределением удовлетворённости людей уволившихся и оставшихся в компании

# %%
test_features_df_new.head()
# Out:
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary
# 0                   no                      5   28800
# 1                   no                      4   30000
# 2                   no                      4   19200
# 3                   no                      4   19200
# 4                   no                      5   40800

# %%
test_features_df_merged = test_features_df_new.merge(test_target_quit_df, on = 'id', how = 'left')

# %%
X_test_new = test_features_df_merged.drop(['id', 'quit'], axis = 1)

# %%
test_features_df_merged['job_satisfaction_rate'] = randomized_search.predict(X_test_new).round(2)

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (15, 5))
hist_build(test_features_df_merged.loc[test_features_df_merged['quit'] == 'no'],
           'job_satisfaction_rate',
           'dodgerblue',
           'Удовлетворённость сотрудников',
           'Количество',
           'Распредление удовлетворённости неуволившихся сотрудников',
           0,
           0,
           20,
           False)
hist_build(test_features_df_merged.loc[test_features_df_merged['quit'] == 'yes'],
           'job_satisfaction_rate',
           'dodgerblue',
           'Удовлетворённость сотрудников',
           'Количество',
           'Распредление удовлетворённости уволившихся сотрудников',
           0,
           1,
           20,
           False)

# %%
sns.histplot(data = test_features_df_merged, x= 'job_satisfaction_rate', hue='quit', bins=50);
plt.title("Сравнение распределения удовлетворённости уволенных и оставшихся сотрудников");
plt.xlabel('Удовлетворённость сотрудников');
plt.ylabel('Количество');

# %% [markdown]
# - По гистограммам видно, что основная часть сотрудников, продолжающих работать в компании, составляет более 0.6
# - В то время как для уволившихся сотрудников основная часть сконцентрированан в области менее 0.6. Более того, на этой гистограмме число людей убывает с ростом удорвлетворённости, а на первой всё наоборот

# %% [markdown]
# ### Выводы по исследовательскому анализу данных:
# - Данные с входными признаками обладают такими же распределениями, как и предыдущие датасеты в задаче №1
# - Выбросы не удалял, так как они не критичны
# - По итогам составления портрета "уволившегося сотрудника" было выяснено, что наиболее часто увольняются сотрудники с низким уровнем должности `junior`(`level`), с низким уровнем загруженности `low`(`workload`), работающие в отделе `technology`(`dept` - увольняемость составляет 30%). Также был выявлен тот факт, что у увольняющихся сотрудников зарплата меньше, чем у продолжающих работать.(присутствуют случаи, когда наоборот, но они редки)

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Хорошо. Добавлю, что сравнение распределений признака job_satisfaction_rate для ушедших и оставшихся работников можно провести с использованием стат теста

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента v2: <a class="tocSkip"> </h2>
#
# <b>Добавил визуализацию распределения признака удовлетворённости (`job_satisfaction_rate`) для обоих случаев признака `quit`</b> на одной гистограмме
# </div>
#
# <br/>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# # Шаг 4. Добавление нового входного признака

# %% [markdown]
# - Так как связь `job_satisfaction_rate` и `quit` была выявлена, то добавим признак `job_satisfaction_rate` и в тренировочную выборку, предсказав его лучшей моделью

# %%
train_quit_df['job_satisfaction_rate'] = randomized_search.predict(X_train_new).round(2)

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b> Ранее этот комментарий был передан тебе через куратора
#
# Кодирование таргетов не следует делать руками.
#
# - при появлении новых значений категориальных признаков, не предусмотренных нашим кодом, модель или упадёт, или будет генерировать ошибки;
# - такое решение не сделать частью пайплайна, а все современные решения базируются на них.
#
# Для кодирования целевого признака нужно использовать LabelEncoder: https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html.
#
#
#     le = LabelEncoder()
#     le.fit_transform(X_train['quit'])
#     le.transform(X_test['quit'])

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента v3: <a class="tocSkip"> </h2>
#
# <b>Кодирование целевого признака методом LabelEncoder перенёс в этап `подготовки данных` </b>
# </div>
#
# <br/>

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера 3 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Чтобы не было утечки в тестовую выборку обучать `LabelEncoder()` следует на тренировочной выборке, а потом метод `transform` уже применять ко всем выборкам. Исправь пожалуйста
#
#
# Напоминаю тебе об ограничении итераций ревью (не более шести проверок): у нас осталось еще 2 проверки, надеюсь, что ты справишься

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента v4: <a class="tocSkip"> </h2>
#
# <b>Исправил ошибку</b>
# </div>
#
# <br/>

# %%
train_quit_df.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit  \
# 0                   no                      4   54000   no
# 1                   no                      4   27600   no
# 2                   no                      1   37200   no
# 3                  yes                      3   24000  yes
# 4                   no                      5   25200   no
#
#    job_satisfaction_rate
# 0                   0.66
# 1                   0.82
# 2                   0.36
# 3                   0.34
# 4                   0.69

# %%
test_features_df_merged.head()
# Out:
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary quit  \
# 0                   no                      5   28800   no
# 1                   no                      4   30000   no
# 2                   no                      4   19200   no
# 3                   no                      4   19200   no
# 4                   no                      5   40800   no
#
#    job_satisfaction_rate
# 0                   0.88
# 1                   0.68
# 2                   0.66
# 3                   0.67
# 4                   0.82

# %% [markdown]
# - Теперь структура тренировочной и тестовой выборки идентичная

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Хорошо, признак job_satisfaction_rate добавлен в тренировочную и тестовую выборки, а значения предсказаны с помощью лучшей модели регрессии, обученной в прошлой части задачи

# %% [markdown]
# # Шаг 5. Подготовка данных

# %% [markdown]
# - Разделение признаков проведём по тому же принципу, что и в задаче №1. Только добавим входной признак `job_satisfaction_rate` в список для масштабирования количественных признаков

# %%
# Объявим категеориальные и количественные признаки
ohe_columns_2 = [
               'dept',
               'last_year_promo',
               'last_year_violations'
              ]

ord_columns_2 = [
               'level',
               'workload'
              ]

num_columns_2 = [
               'employment_years',
               'supervisor_evaluation',
               'salary',
               'job_satisfaction_rate'
              ]

# %% [markdown]
# - Кодирование целевого признака проведём методом LabelEncoder()

# %%
# Деление данных на выборки
X_train = train_quit_df.drop(['id', 'quit'], axis = 1)
y_train = train_quit_df['quit']
X_test = test_features_df_merged.drop(['id', 'quit'], axis = 1)
y_test = test_features_df_merged['quit']

#Добавил на этом этапе кодирование целевого признака quit методом LabelEncoder()
le = LabelEncoder()
le.fit_transform(y_train)
le.transform(y_test)
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера 3 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Чтобы не было утечки в тестовую выборку обучать `LabelEncoder()` следует на тренировочной выборке, а потом метод `transform` уже применять ко всем выборкам. Исправь пожалуйста
#  </div>

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента v4: <a class="tocSkip"> </h2>
#
# <b>Обучил `LabelEncoder` на тренировочной выборке методом `fit_transform`, а затем тестовую выборку методом `transform`. Не заметил, что в предыдущий раз к обеим выборкам применил `fit_transform`</b>
# </div>
#
# <br/>

# %%
# Пайплайн для кодирования и масштабирования данных
data_preprocessor2 = ColumnTransformer(
    [
        ('ohe', ohe_pipe, ohe_columns_2),
        ('ord', ord_pipe, ord_columns_2),
        ('num', MinMaxScaler(), num_columns_2)
    ],
    remainder = 'passthrough'
)

# %% [markdown]
# - Структура data_preprocessor та же, заменим только колонки для масштабирования и кодирования

# %% [markdown]
# - Для предсказания целевого признака воспользуемся тремя моделями : LogisticRegression, DecisionTreeClassfier, KNeighborsClassifier

# %%
# Словарь для RandomimzedSearchCV
param_distributions2 = [
            {
                 # Описание KNeighborsClassifier
                'models' : [KNeighborsClassifier()],
                'models__n_neighbors' : range(4, 8),
                'preprocessor__num' : [StandardScaler(), MinMaxScaler(), RobustScaler()]
            },
            {
                # Описание DecisionTreeClassifier
                'models' : [DecisionTreeClassifier(random_state = RANDOM_STATE)],
                'models__max_depth' : range(5, 12),
                'models__min_samples_split' : range(5, 12),
                'preprocessor__num' : [StandardScaler(), MinMaxScaler(), RobustScaler()]
            },
            {
                # Описание LogisticRegression
                'models' : [LogisticRegression(
                                                random_state = RANDOM_STATE,
                                                solver = 'liblinear',
                                                penalty = 'l1'
                                              )
                           ],
                'models__C' : [0.1, 1, 10],
                'preprocessor__num' : [StandardScaler(), MinMaxScaler(), RobustScaler()]
            }
]

# %%
pipe_final2 = Pipeline([
    ('preprocessor', data_preprocessor2),
    ('models', DecisionTreeClassifier(random_state = RANDOM_STATE)) 
])

# %% [markdown]
# # Шаг 6. Обучение моделей

# %%
# Обучим и найдём лучшую модель при помощи инструмента автоматизированного поиска RandomizedSearchCV
randomized_search2 = RandomizedSearchCV(
                        pipe_final2,
                        param_distributions = param_distributions2,
                        cv = 5,
                        scoring = 'roc_auc',
                        random_state = RANDOM_STATE,
                        n_jobs = -1
                    )
randomized_search2.fit(X_train, y_train)
rs2 = randomized_search2.fit(X_train, y_train)
print('Лучшая модель и её параметры:\n\n', randomized_search2.best_estimator_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['dept', 'last_year_promo',
#                                                    'last_year_violations']),
#                                                  ('ord',
# ...

# %%
print('Метрика лучшей модели на тренировочной выборке:', round((randomized_search2.best_score_), 3))
y_pred = randomized_search2.predict_proba(X_test)[:, 1]
print('Значение метрики на тестовых данных:', round(roc_auc_score(y_test, y_pred), 3))
best_model2 = randomized_search2.best_estimator_
# Out:
# Метрика лучшей модели на тренировочной выборке: 0.929
# Значение метрики на тестовых данных: 0.923

# %% [markdown]
# - Значение метрики $ROC-AUC$ на тестовой выборке удовлетворяет условию задания ($>=0.91$)
# - Лучшей моделью оказалось дерево решений. Посмотрим, какие входные признаки оказали наибольшее влияние на целевой признак

# %%
X_train_new = pipe_final.named_steps['preprocessor'].fit_transform(X_train)
X_test_new = pipe_final.named_steps['preprocessor'].transform(X_test)
feature_names = pipe_final.named_steps['preprocessor'].get_feature_names_out()
X_test_new = pd.DataFrame(X_test_new, columns=feature_names)
model = randomized_search.best_estimator_.named_steps['models']

# %%
viz = FeatureImportances(model);
viz.fit(X_test_new, y_test);
viz.show();

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (15, 5))
hist_build(test_features_df_merged.loc[test_features_df_merged['quit'] == 'no'],
           'supervisor_evaluation',
           'lightgreen',
           'Оценка работодателя',
           'Количество',
           'Распределение оценки работодателя неуволившихся сотрудников',
           0,
           0,
           5,
           False)
hist_build(test_features_df_merged.loc[test_features_df_merged['quit'] == 'yes'],
           'supervisor_evaluation',
           'lightgreen',
           'Удовлетворённость сотрудников',
           'Количество',
           'Распределение оценка работодателя уволившихся сотрудников',
           0,
           1,
           5,
           False)

# %%
employment_years_pivot_table = (train_quit_df[['id','workload', 'dept', 'level', 'quit', 'employment_years']]
                      .pivot_table(index = ['dept', 'level', 'workload', 'quit'], values = ['employment_years'], aggfunc = ['mean']))

# %%
employment_years_pivot_table.columns = ['mean_employment_years']
employment_years_pivot_table['mean_employment_years'] = employment_years_pivot_table['mean_employment_years'].round(2)

# %%
for column in dept_col:
    display(employment_years_pivot_table.loc[employment_years_pivot_table.index.get_level_values(0) == column])
    print(' ')
    print(' ')
# Out:
#                            mean_employment_years
# dept level  workload quit
# hr   junior high     no                     2.40
#                      yes                    1.17
#             low      no                     2.48
#                      yes                    1.71
#             medium   no                     2.29
#                      yes                    1.56
#      middle high     no                     5.42
#                      yes                    4.00
#             low      no                     5.73
#                      yes                    2.64
#             medium   no                     5.05
#      senior high     no                     6.00
#             low      no                     7.29
#             medium   no                     6.00
#                      yes                    2.00
#                                 mean_employment_years
# dept      level  workload quit
# marketing junior high     no                     1.86
# ...

# %% [markdown]
# # Шаг 7. Выводы

# %% [markdown]
# - Лучшей моделью оказалось дерево решений с гиперпараметрами `max_depth` = 5, `min_samples_split` = 5. Метрика на тестовой выборке оказалась равной 0.923
# - Данный результат связан с тем, что дерево решений способно более гибко адаптироваться под обучающую выборку и хорошо учитывать условия, которые наблюдаются в данных, в отличии от логистической регресии и метода ближайших соседей
# - Наибольшее влияние на целевой признак оказывает оценка работодателя (`supervisor_evaluation`). Сотрудники, которые увольняются, обладают более низкими оценками работодателя
# - Признаки `salary` и `employment_years` обладают примерно одинаковым влиянием на целевой признак `quit`, но не таким значительным, как у `supervisor_evaluation`. Иными словами, более низкая зарплата способствует увольнению.
# - У уволившихся сотрудников также меньше длительность работы в компании(`employment_years`), чем у неуволившихся
# - На целевой признак также оказывает влияние `last_year_violations`. Если у сотрудника присутствует нарушение, то больше вероятность, что он уволится (или его уволят)
# - И последний признак, который следует учитывать, - `level`. Чем меньше загруженность у сотрудников, тем чаще они увольняются

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# На тестовой выборке получено хорошее качество)

# %% [markdown]
# # Общий вывод

# %% [markdown]
# - Поставленная задача в проекте заключалась в предсказании оттока специалистов, а также в прогнозировании уровня их удовлетворённости работой. Для её решения было разработано 2 модели, которая предсказывала целевые признаки(удовлетворённость работой, увольнение), указанные в задании(модель №1 - `job_satisfaction_rate`, модель №2 - `quit`).
# - В ходе решения каждой из задач были проведены стандартные этапы работы с данными, а именно загрузка данных из датасетов, их предобработка и анализ.
#     + При построении диаграмм для задачи №1 (исследовательский анализ данных) критических замечаний не было обнаружено - выбросы были оставлены без изменений, так как они не сильно выбивались от основной группы данных. Информация о том, как распределены сотрудники из отделов и прочие сведения, визуализирована на круговых диаграммах
#     + В задаче №2 были проведены все те же самые операции, что и в задаче №1. СТруктура, распределение и прочие свойства данных идентичны
# - По результатам обучения моделей было получено следующее:
#     + В случае с задачей №1:
#         * Лучшей моделью оказалось дерево регрессий с гиперпараметрами `max_depth` = 12, `min_samples_split` = 11. В качестве скейлера был выбран RobustScaler. По итогу обучения на тестовой выборке было получено значение метрики `SMAPE` = 13.9
#         * После проведения анализа значимости признаков в предсказаний модели были замечены следующие закономерности:
#         * `supervisor_evaluation` оказывает наибольший вклад при выборе решения моделью (оценка работодателя)
#         * `employment_years`, `salary`, `level` - в первом приближении равны по значимости, при этом их вклад на принятие решение в 2.5 меньше, чем признака `supervisor_evaluation`
#         * `last_year_violations`, `workload`, `dept` менее значимы (вклад в принятие решений моделью в 5 раз меньше, чем `super_visor_violations`)
#         * `last_year_promo` почти не влияет на целевой признак в сравнении с другими входными признаками
#     + Для задачи №2 сформулированы другие замечания и показатели, так как предсказывался бинарный признак, а не непрерывный количественный, как в предыдущей задаче:
#         * Здесь лучшей моделью стало дерево решений с гиперпараметрами `max_depth` = 5, `min_samples_split` = 5. Для масштабирования количественных данных был выбран MinMaxScaler. Значение метрики `ROC-AUC` на тестовой выборке оказалось 0.923
#         * После полученных показателей был проводён анализ значимости для выявления входных признаков, которые оказывают наибольший вклад в предсказание целевого признака.
#         * Наибольшее влияние на целевой признак оказывает оценка работодателя (`supervisor_evaluation`). Сотрудники, которые увольняются, обладают более низкими оценками работодателя
#         * Признаки `salary` и `employment_years` обладают примерно одинаковым влиянием на целевой признак `quit`, но не таким значительным, как у `supervisor_evaluation`. Иными словами, более низкая зарплата способствует увольнению.
#         * У уволившихся сотрудников также меньше длительность работы в компании(`employment_years`), чем у неуволившихся
#         * На целевой признак также оказывает влияние `last_year_violations`. Если у сотрудника присутствует нарушение, то больше вероятность, что он уволится (или его уволят)
#         * И последний признак, который следует учитывать, - `level`. Чем меньше загруженность у сотрудников, тем чаще они увольняются
# - Инсайты и совету бизнесу по результатам проделанной работы:
#     - 1. Наиболее часто увольняются сотрудники, которые находятся на невысокой должности с низким уровнем нагрузки. Если есть возможность, то необходимо таких сотрудников по результатам определённого периода работы оценивать и повышать должность, если он соответсвует более высокому уровню, чтобы человек чувствовал движение по карьерной лестнице и мотивацию продолжать деятельность в соответствующей компании.
#     - 2. При этом важно не забывать про более квалифицированных работников уровня `senior` и обеспечивать требуемые условия, так как уход такого рода сотрудников может привести к более значительным потерям компании, нежели выплата повышенной зарплаты.
#     - 3. При подборе персонала следует тщательнее обращать внимание на работу сотрудника в других организациях(на его характерстику), так как люди, нарушающие трудовой договор и оценка качества работы которых сравнительно низкая, чаще увольняются.
#     - 4. Стоит обратить внимание на длительность работы в предыдущих компаниях. Если человек часто меняет место работы - это также один факторов, почему человек с большей вероятность может уволится
#     - 5. Несмотря на то, что модель не придала огромного значения признаку удовлетворённости, тем не менее на этот показатель нужно также обращать внимание, так как его низкое значение способствует оттоку кадров. А эта характеристика в свою очередь зависит от уровня должности, зарплаты, нагруженности сотрудника

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Молодец, что не забываешь про итоговый вывод и рекомендации для бизнеса

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера (общий вывод по проекту) <a class="tocSkip"> </h2>
#
#
# У меня сложилось хорошее общее впечатление о проекте, тебе удалось неплохо справиться с этим проектом. Молодец! Подготовлены данные для анализа, изучен каждый параметр. Все красиво визуализировано, построено несколько моделей регрессии/ классификации и оценено их качество. Осмысленная аналитика и дельная модельная работа - многое удалось как надо)
#
# Отмечу отдельные положительные моменты проекта🙂:
#
# - в ходе проекта встречались  функции, помогающие избавиться от дублирования кода;
# - много красивых визуализаций в проекте и хорошая интерпретация;
# - при обучении моделей использованы пайплайны, кросс-валидация и поиск гиперпараметров.
#
# Есть несколько моментов всего, на которые стоит ещё раз взглянуть, я указал их в моих комментариях по ходу проекта. Предлагаю тебе доработать проект по моим комментариям, чтобы довести его до совершенства.
#
#
#
# </div>
